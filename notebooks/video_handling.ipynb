# %% [markdown]
# # Video Handling

# %% [markdown]
# Necessary libraries

# %%
import os
import sys
import matplotlib.pyplot as plt
from google.colab import drive
import cv2
import numpy as np

# %% [markdown]
# Mouting my repository

# %%
drive.mount('/content/drive', force_remount=True)

# FOLDERNAME = 'repo'
# sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
sys.path.append('/content/drive/My Drive/repo/codes')
from utils import video_utils
# Out:
# Mounted at /content/drive

# %% [markdown]
# make matplotlib figures apper inline in the notebook rather than in a new window.

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (12.0, 10.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20

# %% [markdown]
# # Choosing video

# %%
video_path = '/content/drive/My Drive/repo/Excidio Mosquitoes/Dataset/2018-07-19'
video_name = 'DJI_0001.MOV'
video = os.path.join(video_path, video_name)

# %% [markdown]
# # Creating video object

# %%
video_obj = video_utils.videoObj(videopath=video)

# %% [markdown]
# # Getting a certain frame

# %%
#The get_frame method capture a certain frame by its number
#The example bellow capture de 20th number

ret, frame, frame_size = video_obj.get_frame(frame_req=20)

# %% [markdown]
# # Displaying frame

# %%
#displaying frame
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
print('image size: ', frame_size)
# Out:
# image size:  (2160, 4096, 3)
