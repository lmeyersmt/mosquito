# %% [markdown]
# ## Comparing speed and phase correlation confiability

# %%
#phase correlation libraries
import numpy as np
from scipy import misc
from argparse import ArgumentParser

#complementary labraries
from google.colab import drive
import sys
import os
import matplotlib.pyplot as plt
import cv2
import pandas as pd

# %%
drive.mount('/content/drive', force_remount=True)

sys.path.append('/content/drive/My Drive/repo/codes/')
from utils import video_utils
# Out:
# Mounted at /content/drive

# %%
log_path = '/content/drive/MyDrive/repo/Excidio Mosquitoes/Dataset/_under_construction/flightlogs/interpolated/'
log_name = '20190601_rectified_DJI_0006_interp.csv'

# video_path = '/content/drive/MyDrive/repo/Excidio Mosquitoes/Dataset/_under_construction/videos/'
# video_name = '20190601_rectfied_DJI_0006.avi'

# %%
# video = os.path.join(video_path, video_name)

# %%
# video_obj = video_utils.videoObj(videopath=video)
# video_capture = cv2.VideoCapture(video)

# %%
df = pd.read_csv(log_path + log_name)

# %%
df['speed(mps)']
# Out:
# 0       7.98
# 1       7.98
# 2       7.98
# 3       7.98
# 4       7.98
#         ...
# 7853    7.95
# 7854    7.95
# 7855    7.95
# 7856    7.95
# 7857    7.95
# Name: speed(mps), Length: 7858, dtype: float64
